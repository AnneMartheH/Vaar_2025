# %%
#import for HYPSO
from hypso import Hypso1, Hypso2
import os 
import matplotlib.pyplot as plt
from global_land_mask import globe 
import numpy as np 

import funcions_autonom as f
import xarray as xr #for cla estimasjon

# %%
dir_path = "."
 
i_250504 = os.path.join(dir_path, "image62N6E_2025-05-04T11-25-43Z-l1a.nc")
i_250504_b = os.path.join(dir_path, "image62N6E_2025-05-04T11-25-43Z-l1b.nc")
i_250504_c = os.path.join(dir_path, "image62N6E_2025-05-04T11-25-43Z-l1c.nc")
i_250504_d = os.path.join(dir_path, "image62N6E_2025-05-04T11-25-43Z-l1d.nc")

satobj_h1_250504 = Hypso1( path = i_250504, verbose = True )

l1a_cube_250504 = satobj_h1_250504.l1a_cube
l1b_cube_250504 = Hypso1( path = i_250504_b, verbose = True )
l1c_cube_250504 = Hypso1( path = i_250504_c, verbose = True )
l1d_cube_250504 = Hypso1( path = i_250504_d, verbose = True )

l1c_cube_250504 = l1c_cube_250504.l1c_cube
l1b_cube_250504 = l1b_cube_250504.l1b_cube
l1d_cube_250504 = l1d_cube_250504.l1d_cube

satobj_h1_250504.run_direct_georeferencing() # in order to get the longiyudes and latitudes
# Out:
# [INFO] Loading L1a capture image62N6E_2025-05-04T11-25-43Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1b capture image62N6E_2025-05-04T11-25-43Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1c capture image62N6E_2025-05-04T11-25-43Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1d capture image62N6E_2025-05-04T11-25-43Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Running direct georeferencing...
# [INFO] ADCS samples: 539
# [INFO] ADCS time range: 1746357300.000000 to 1746358200.000000
# [INFO] Frame time range: 1746357943.890893 to 1746358018.515893
# [INFO] 299 sample(s) inside frame time range
# [INFO] Interpolating 598 frames
# [INFO] Computing pixel latitude and longitude coordinates ...
# [INFO] Interpolating pixel coordinate gaps...
# ...

# %%
i_250511 = os.path.join(dir_path, "image63N6E_2025-05-11T10-25-37Z-l1a.nc")
i_250511_b = os.path.join(dir_path, "image63N6E_2025-05-11T10-25-37Z-l1b.nc")
i_250511_c = os.path.join(dir_path, "image63N6E_2025-05-11T10-25-37Z-l1c.nc")
i_250511_d = os.path.join(dir_path, "image63N6E_2025-05-11T10-25-37Z-l1d.nc")

satobj_h1_250511 = Hypso1( path = i_250511, verbose = True )

l1a_cube_250511 = satobj_h1_250511.l1a_cube
l1b_cube_250511 = Hypso1( path = i_250511_b, verbose = True )
l1c_cube_250511 = Hypso1( path = i_250511_c, verbose = True )
l1d_cube_250511 = Hypso1( path = i_250511_d, verbose = True )

l1c_cube_250511 = l1c_cube_250511.l1c_cube
l1b_cube_250511 = l1b_cube_250511.l1b_cube
l1d_cube_250511 = l1d_cube_250511.l1d_cube

satobj_h1_250511.run_direct_georeferencing() # in order to get the longiyudes and latitudes
# Out:
# [INFO] Loading L1a capture image63N6E_2025-05-11T10-25-37Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1b capture image63N6E_2025-05-11T10-25-37Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1c capture image63N6E_2025-05-11T10-25-37Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1d capture image63N6E_2025-05-11T10-25-37Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       9 l1b_cube_250511 = Hypso1( path = i_250511_b, verbose = True )
#      10 l1c_cube_250511 = Hypso1( path = i_250511_c, verbose = True )
# ---> 11 l1d_cube_250511 = Hypso1( path = i_250511_d, verbose = True )
#      13 l1c_cube_250511 = l1c_cube_250511.l1c_cube
#      14 l1b_cube_250511 = l1b_cube_250511.l1b_cube
# ...

# %%
i_250511_2 = os.path.join(dir_path, "image64N9E_2025-05-11T12-00-37Z-l1a.nc")
i_250511_2_b = os.path.join(dir_path, "image64N9E_2025-05-11T12-00-37Z-l1b.nc")
i_250511_2_c = os.path.join(dir_path, "image64N9E_2025-05-11T12-00-37Z-l1c.nc")
i_250511_2_d = os.path.join(dir_path, "image64N9E_2025-05-11T12-00-37Z-l1d.nc")

satobj_h1_250511_2 = Hypso1( path = i_250511_2, verbose = True )

l1a_cube_250511_2 = satobj_h1_250511_2.l1a_cube
l1b_cube_250511_2 = Hypso1( path = i_250511_2_b, verbose = True )
l1c_cube_250511_2 = Hypso1( path = i_250511_2_c, verbose = True )
l1d_cube_250511_2 = Hypso1( path = i_250511_2_d, verbose = True )

l1c_cube_250511_2 = l1c_cube_250511_2.l1c_cube
l1b_cube_250511_2 = l1b_cube_250511_2.l1b_cube
l1d_cube_250511_2 = l1d_cube_250511_2.l1d_cube

satobj_h1_250511_2.run_direct_georeferencing() # in order to get the longiyudes and latitudes
# Out:
# [INFO] Loading L1a capture image64N9E_2025-05-11T12-00-37Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1b capture image64N9E_2025-05-11T12-00-37Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1c capture image64N9E_2025-05-11T12-00-37Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Loading L1d capture image64N9E_2025-05-11T12-00-37Z
# [INFO] Capture spatial dimensions: (598, 1092)
# [INFO] Capture capture type: wide
# [INFO] Running direct georeferencing...
# [INFO] ADCS samples: 540
# [INFO] ADCS time range: 1746964170.000000 to 1746965100.000000
# [INFO] Frame time range: 1746964837.479518 to 1746964912.104518
# [INFO] 299 sample(s) inside frame time range
# [INFO] Interpolating 598 frames
# [INFO] Computing pixel latitude and longitude coordinates ...
# [INFO] Interpolating pixel coordinate gaps...
# ...

# %%
x_1 = [387.84749685, 391.40406599, 394.95941579, 398.51354623, 402.06645732, 405.61814905, 409.16862143, 412.71787446, 416.26590814, 419.81272246, 423.35831743, 426.90269305, 430.44584931, 433.98778622, 437.52850378, 441.06800198, 444.60628083, 448.14334033, 451.67918047, 455.21380126, 458.7472027, 462.27938479, 465.81034752, 469.3400909 , 472.86861492,476.3959196 , 479.92200491, 483.44687088, 486.97051749, 490.49294475,494.01415266, 497.53414122, 501.05291042, 504.57046026, 508.08679076,511.6019019 , 515.11579369, 518.62846612, 522.13991921, 525.65015294,529.15916731, 532.66696233, 536.173538  , 539.67889432, 543.18303128,546.68594889, 550.18764715, 553.68812606, 557.18738561, 560.68542581,564.18224665, 567.67784814, 571.17223028, 574.66539307, 578.1573365, 581.64806058, 585.1375653 , 588.62585068, 592.1129167 , 595.59876336,599.08339068, 602.56679864, 606.04898725, 609.5299565 , 613.0097064 ,616.48823695, 619.96554815, 623.44163999, 626.91651248, 630.39016561,633.86259939, 637.33381382, 640.8038089 , 644.27258462, 647.74014099,651.20647801, 654.67159568, 658.13549399, 661.59817294, 665.05963255,668.5198728 , 671.9788937 , 675.43669524, 678.89327744, 682.34864028,685.80278376, 689.25570789, 692.70741267, 696.1578981 , 699.60716418,703.0552109 , 706.50203826, 709.94764628, 713.39203494, 716.83520425,720.2771542 , 723.7178848 , 727.15739605, 730.59568795, 734.03276049,737.46861368, 740.90324752, 744.336662  , 747.76885713, 751.19983291,754.62958933, 758.0581264 , 761.48544412, 764.91154248, 768.33642149,771.76008115, 775.18252146, 778.60374241, 782.02374401, 785.44252625,788.86008915, 792.27643269, 795.69155687, 799.10546171, 802.51814719]
x=x_1[5:115]

# Target latitude and longitude
#target_lat = [64.08533976025561,64.08799001499494, 64.00671553632209, 64.00539040895242] #område 1.
#target_lon = [9.744011353487297, 9.632700654435348, 9.740919389624743,9.634025781805015]  

#target_lat = [63.818490304354434,63.793837321385155, 63.65192496143867, 63.660555970548074] #område 2.1.
#target_lon = [9.531415429238418, 9.442656298818237,9.526455044589706,9.439764451470932]

#target_lat = [64.2750935781297,64.29365394014144, 64.17902661492639, 64.18553880683058] #område 4, korrigert
#target_lon = [9.127764312954888, 8.585899068865604,9.130324490159921,8.564058182856481]  

#target_lat = [63.646767083517425,63.61771951990031, 63.47865598622861, 63.42721372576498] #område 5.1
#target_lon = [9.804697410334523, 9.723689711502818,10.061035990832918,9.982929114384596]  

target_lat = [64.17324887890479,64.11631446557637, 63.896904083590066, 63.887923483169004] #område 6.1
target_lon = [9.582148298814932,8.924448409066027, 9.578289180688513, 8.96230357578283]

#target_lat = [64.48557437461893,64.52896641587218, 64.20992561747796, 64.22009411667561] #område 7
#target_lon = [9.886201113342556, 8.708294855080245,9.704720121565003,8.73032214102829]

# %%
latitudes_250504 = satobj_h1_250504.latitudes
longitudes_250504 = satobj_h1_250504.longitudes

piksel_row_250504, piksel_col_250504 = f.latLong_to_piksel(target_lat, target_lon, latitudes_250504, longitudes_250504) #from file funcions_autonom.py
#rss_matrix_0328 = f.rss_matrix(120, piksel_row_0328,piksel_col_0328, l1d_cube_0328)
rss_matrix_250504 = f.water_masked_rss_matrix(piksel_row_250504,piksel_col_250504, l1d_cube_250504, satobj_h1_250504)
        
mean_spectrum_250504 = np.mean(rss_matrix_250504, axis=1) ## mean over rad  # gjenomsnitt
median_spectrum_250504 = np.median(rss_matrix_250504, axis=1) # median over rad
std_spectrum_250504 = np.std(rss_matrix_250504, axis=1)  #standard avik

normaized_spectrum_250504 = f.min_max_nomralization(mean_spectrum_250504)
normaized_spectrum_median_250504 = f.min_max_nomralization(median_spectrum_250504)

l2_norm_250504 = np.linalg.norm(mean_spectrum_250504)  #l2 norm
l2_normalized_spectrum_250504 = mean_spectrum_250504 / l2_norm_250504  #l2 normalisering

l2_norm_median_250504 = np.linalg.norm(median_spectrum_250504)  #l2 norm
l2_normalized_median_spectrum_250504 = median_spectrum_250504 / l2_norm_median_250504  #l2 normalisering
# Out:
# Pixel number:  2

# %%
print(latitudes_250504[1][1])
print(longitudes_250504[1][1])
# Out:
# 64.04524481332092
# 8.818243533391247

# %%
latitudes_250511 = satobj_h1_250511.latitudes
longitudes_250511 = satobj_h1_250511.longitudes

piksel_row_250511, piksel_col_250511 = f.latLong_to_piksel(target_lat, target_lon, latitudes_250511, longitudes_250511) #from file funcions_autonom.py
#rss_matrix_0328 = f.rss_matrix(120, piksel_row_0328,piksel_col_0328, l1d_cube_0328)
rss_matrix_250511 = f.water_masked_rss_matrix(piksel_row_250511,piksel_col_250511, l1d_cube_250511, satobj_h1_250511)
        
mean_spectrum_250511 = np.mean(rss_matrix_250511, axis=1) ## mean over rad  # gjenomsnitt
median_spectrum_250511 = np.median(rss_matrix_250511, axis=1) # median over rad
std_spectrum_250511 = np.std(rss_matrix_250511, axis=1)  #standard avik

normaized_spectrum_250511 = f.min_max_nomralization(mean_spectrum_250511)
normaized_spectrum_median_250511 = f.min_max_nomralization(median_spectrum_250511)

l2_norm_250511 = np.linalg.norm(mean_spectrum_250511)  #l2 norm
l2_normalized_spectrum_250511 = mean_spectrum_250511 / l2_norm_250511  #l2 normalisering

l2_norm_median_250511 = np.linalg.norm(median_spectrum_250511)  #l2 norm
l2_normalized_median_spectrum_250511 = median_spectrum_250511 / l2_norm_median_250511  #l2 normalisering
# Out:
# Pixel number:  30

# %%
latitudes_250511_2 = satobj_h1_250511_2.latitudes
longitudes_250511_2 = satobj_h1_250511_2.longitudes

piksel_row_250511_2, piksel_col_250511_2 = f.latLong_to_piksel(target_lat, target_lon, latitudes_250511_2, longitudes_250511_2) #from file funcions_autonom.py
#rss_matrix_0328 = f.rss_matrix(120, piksel_row_0328,piksel_col_0328, l1d_cube_0328)
rss_matrix_250511_2 = f.water_masked_rss_matrix(piksel_row_250511_2,piksel_col_250511_2, l1d_cube_250511_2, satobj_h1_250511_2)
        
mean_spectrum_250511_2 = np.mean(rss_matrix_250511_2, axis=1) ## mean over rad  # gjenomsnitt
median_spectrum_250511_2 = np.median(rss_matrix_250511_2, axis=1) # median over rad
std_spectrum_250511_2 = np.std(rss_matrix_250511_2, axis=1)  #standard avik

normaized_spectrum_250511_2 = f.min_max_nomralization(mean_spectrum_250511_2)
normaized_spectrum_median_250511_2 = f.min_max_nomralization(median_spectrum_250511_2)

l2_norm_250511_2 = np.linalg.norm(mean_spectrum_250511_2)  #l2 norm
l2_normalized_spectrum_250511_2 = mean_spectrum_250511_2 / l2_norm_250511_2  #l2 normalisering

l2_norm_median_250511_2 = np.linalg.norm(median_spectrum_250511_2)  #l2 norm
l2_normalized_median_spectrum_250511_2 = median_spectrum_250511_2 / l2_norm_median_250511_2  #l2 normalisering
# Out:
# Pixel number:  265

# %%
plt.plot(x, median_spectrum_250504, color='blue', label='median 250504 = 2 pixel')
plt.plot(x, median_spectrum_250511, color='black', label='median 250511')

plt.plot(x, median_spectrum_250511_2, color='red', linestyle='--', label='median 250411_2')





################################### normalized spectrums with mean  ###################################
 #plt.plot(x, normaized_spectrum, color='black', label='0316')
# plt.plot(x, normaized_spectrum_0328, color='black')
# plt.plot(x, normaized_spectrum_0329, color='black')
# plt.plot(x, normaized_spectrum_0330, color='black')
# 
#plt.plot(x, normaized_spectrum_0407, color='blue', label=' normalized 0407')
#plt.plot(x, normaized_spectrum_0412, color='blue', label='normalized 0412')
# 
# plt.plot(x, normaized_spectrum_0614, color='red')
# plt.plot(x, normaized_spectrum_0730, color='pink')

#plt.plot(x, normaized_spectrum_24_0310, color='purple', label='24 0310') -> 1 piksel

#plt.plot(x, normaized_spectrum_24_0419, color='blue')
#plt.plot(x, normaized_spectrum_24_0426, color='blue', label=' Apr')

#plt.plot(x, normaized_spectrum_24_0506, color='red')
#plt.plot(x, normaized_spectrum_24_0524, color='red', label=' May')

#plt.plot(x, normaized_spectrum_24_0713, color='pink', label=' Jul')
#plt.plot(x, normaized_spectrum_24_0615, color='red', label=' Jun')

#plt.plot(x, normaized_spectrum_t_22_0824, color='green', label='n 0419')

#plt.plot(x, normaized_spectrum_t_24_0911, color='purple')
#plt.plot(x, normaized_spectrum_t_24_0914, color='purple', label='Sep')

################################## normalized spectrums with median  ###################################
#plt.plot(x, normaized_spectrum_median, color='black', label='Mar 23')
#plt.plot(x, normaized_spectrum_median_0328, color='black')
#plt.plot(x, normaized_spectrum_median_0329, color='black')
#plt.plot(x, normaized_spectrum_median_0330, color='red', label='0330')
#
#plt.plot(x, normaized_spectrum_median_0407, color='blue', label = 'Apr 23')
#plt.plot(x, normaized_spectrum_median_0412, color='blue')
#
#plt.plot(x, normaized_spectrum_median_0614, color='indigo', label='Jun 23')
#plt.plot(x, normaized_spectrum_median_0730, color='pink', label='Jul 23')
#
### ikke bruk med område 6.1 #plt.plot(x, normaized_spectrum_median_24_0310, color='black', linestyle = '--', label='Mar 24') #1 piksel
#
#plt.plot(x, normaized_spectrum_median_24_0426, color='blue', linestyle = '--', label=' Apr 24')
#plt.plot(x, normaized_spectrum_median_24_0419, color='blue', linestyle = '--')
#
#plt.plot(x, normaized_spectrum_median_24_0506, color='purple', linestyle = '--', label = 'May 24')
#plt.plot(x, normaized_spectrum_median_t_24_0524, color='purple', linestyle = '--')
#
#plt.plot(x, normaized_spectrum_median_24_0713, color='pink', linestyle = '--', label='Jul 24')
#plt.plot(x, normaized_spectrum_median_24_0615, color='red', linestyle = '--', label=' Jun 24')
#
#plt.plot(x, normaized_spectrum_median_t_22_0824, color='green', label='Aug 22 t')
#
#plt.plot(x, normaized_spectrum_median_t_24_0911, color='purple', linestyle = '--')
#plt.plot(x, normaized_spectrum_median_t_24_0914, color='purple', linestyle = '--', label='Sep 24 t')

############################## l2 normalized spectrums  ###################################

###################################### regarding the plots represenation ##############################
plt.xlabel("Wawelength (nm)")
plt.ylabel("Top-of-Atmosphere Reflectance  [sr^{-1}]") #finne enheten her
plt.title("Min max normalized median spectrum 2022 - 2024")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
